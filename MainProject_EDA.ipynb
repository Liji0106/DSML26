# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_employee = pd.read_csv("C:/Users/LENOVO/Downloads/myexcel - myexcel.csv.csv")
data_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data_employee.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data_employee.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %% [markdown]
# # data cleaning and analysing data:

# %%
data_employee.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
data_employee.shape
# Out:
# (458, 9)

# %%
data_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
data_employee.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data_employee.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
data_employee.duplicated().sum()
# Out:
# 0

# %%
data_employee.nunique()
# Out:
# Name        458
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
random_heights = np.random.randint(150, 181, size=len(data_employee))
data_employee['Height'] = random_heights
data_employee['Height']
# Out:
# 0      165
# 1      166
# 2      150
# 3      178
# 4      172
#       ...
# 453    177
# 454    153
# 455    163
# 456    164
# 457    175
# Name: Height, Length: 458, dtype: int32

# %% [markdown]
# # ANALYSING

# %%
data_employee['Team'].value_counts() #Employees distribution across each team
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#Total number of employee

total= len(data_employee)
print("The total number of employee is : " ,total)
# Out:
# The total number of employee is :  458

# %%
#percentage split relative to the total no. of employees 

percentage_split = ((data_employee['Team'].value_counts())/total)*100
print("Percentage Split : ",percentage_split)
# Out:
# Percentage Split :  Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
#no. of employees based on their positions

employee_position=data_employee['Position'].value_counts()
employee_position
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#grouping employees based on age
bins = [20, 30, 40, 50, 60]
labels = ['20-29', '30-39', '40-49', '50-59']
data_employee['AgeGroup'] = pd.cut(data_employee['Age'], bins=bins, labels=labels, right=False)
age_group_distribution = data_employee['AgeGroup'].value_counts()
print("Age Group Distribution: " ,age_group_distribution)
# Out:
# Age Group Distribution:  AgeGroup
# 20-29    334
# 30-39    119
# 40-49      3
# 50-59      0
# Name: count, dtype: int64

# %%
#Salary expenditure of each team
salary_team=data_employee.groupby('Team')['Salary'].sum()
print("Salary Expenditure of each Team is : ",salary_team)
# Out:
# Salary Expenditure of each Team is :  Team
# Atlanta Hawks              72902950.0
# Boston Celtics             58541068.0
# Brooklyn Nets              52528475.0
# Charlotte Hornets          78340920.0
# Chicago Bulls              86783378.0
# Cleveland Cavaliers       106988689.0
# Dallas Mavericks           71198732.0
# Denver Nuggets             60121930.0
# Detroit Pistons            67168263.0
# Golden State Warriors      88868997.0
# Houston Rockets            75283021.0
# Indiana Pacers             66751826.0
# Los Angeles Clippers       94854640.0
# Los Angeles Lakers         71770431.0
# Memphis Grizzlies          76550880.0
# Miami Heat                 82515673.0
# Milwaukee Bucks            69603517.0
# Minnesota Timberwolves     59709697.0
# New Orleans Pelicans       82750774.0
# New York Knicks            73303898.0
# Oklahoma City Thunder      93765298.0
# Orlando Magic              60161470.0
# Philadelphia 76ers         30992894.0
# ...

# %%
 # Team having highest salary expenditure
highest_team_salary=data_employee.groupby('Team')['Salary'].sum().idxmax() 
print("The Team having Highest Salary Expenditure : ",highest_team_salary)
# Out:
# The Team having Highest Salary Expenditure :  Cleveland Cavaliers

# %%
#Salary expenditure of each position
salary_position=data_employee.groupby('Position')['Salary'].sum()
print("Salary Expenditure of each Position : ",salary_position)
# Out:
# Salary Expenditure of each Position :  Position
# C     466377332.0
# PF    442560850.0
# PG    446848971.0
# SF    408020976.0
# SG    396976258.0
# Name: Salary, dtype: float64

# %%
# # position having highest salary expenditure
highest_position_salary=data_employee.groupby('Position')['Salary'].sum().idxmax() 
print("The Position having Highest Salary Expenditure: ",highest_position_salary)
# Out:
# The Position having Highest Salary Expenditure:  C

# %%
correlation = data_employee['Age'].corr(data_employee['Salary'])
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Salary', data=data_employee)
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
print('Correlation between age and salary:', correlation)
# Out:
# Correlation between age and salary: 0.21400941226570985

# %% [markdown]
# # GRAPHICAL REPRESENTATION

# %%
distribution = data_employee['Team'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(distribution, labels=distribution.index)
plt.title('Distribution of Employees In Each Teams')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Position', data=data_employee)
plt.title('Employees Based on Positions')
plt.xlabel('Position')
plt.ylabel('No. of Employees')
plt.show()

# %%
plt.figure(figsize=(8, 6))
labels = age_group_distribution.index
values = age_group_distribution.values
bars = plt.bar(labels,values,color='blue',width=0.5)
plt.title('Age Group Distribution of Employees')
plt.xlabel('Age Group')
plt.ylabel('No. of Employees')
plt.show()

# %%
team_expenditure = data_employee.groupby('Team')['Salary'].sum() 
plt.figure(figsize=(8, 6))
labels = team_expenditure.index
values = team_expenditure.values
bars = plt.bar(labels,values,color='green',width=0.4)
plt.title('Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.xticks(rotation=90)
plt.show()

# %%
position_expenditure = data_employee.groupby('Position')['Salary'].sum() 
plt.figure(figsize=(8, 6))
labels = position_expenditure.index
values = position_expenditure.values
bars = plt.bar(labels,values,color='red',width=0.5)
plt.title('Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Salary', data=data_employee)
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
